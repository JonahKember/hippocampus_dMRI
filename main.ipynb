# %%
import os
import json
import numpy as np
import nibabel as nib

import preprocessing

with open('config.json') as f:
    config = json.load(f)

preprocessing.create_B0_surface(config)
preprocessing.get_DKT_params(config)
# Out:
# mrtransform: [WARNING] existing output files will be overwritten
# mrtransform: uncompressing image "data/sub-HCD0001305_hemi-L_space-cropT1w_desc-preproc_T1w.nii.gz"... [==================================================]
# mrtransform: preloading data for "data/sub-HCD0001305_hemi-L_space-cropT1w_desc-preproc_T1w.nii.gz"... [==================================================]
# mrtransform: copying from "data/sub-H...T1w_desc-preproc_T1w.nii.gz" to "output/sub...pB0_desc-preproc_T1w.nii.gz"...... [==================================================]
# mrtransform: compressing image "output/sub-HCD0001305_hemi-L_space-cropB0_desc-preproc_T1w.nii.gz"... [==================================================]
# mrgrid: [WARNING] existing output files will be overwritten
# mrgrid: uncompressing image "data/sub-HCD0001305_dwi.nii.gz"... [==================================================]
# ...
